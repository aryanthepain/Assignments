# %% [markdown]
# # Lab Assignment 2 DA221
#
# - Name- Aryan Gupta
# - Roll- 230150003
# - Date- 10/02/25
# - Time- 15:07

# %% [markdown]
# ## Importing Libraries

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Q1

# %% [markdown]
# ## Task 1

# %% [markdown]
# ### Defining initial variables

# %%
# weights
wh11= 0.1
wh12=0.3
wh21=0.3
wh22=0.4
wo11=0.4
wo12=0.6

# input
x1=0.2
x2=0.6

# output
t1=0.7

# learning rate 
alpha=2

# loss function
def loss(a,b):
    return (a-b)**2

# activation function
def sigmoid(v):
    return 1/(1+math.exp(-v))

# %% [markdown]
# ### Forward Pass

# %%
# hidden nuerons
v1=wh11*x1+wh12*x2
v2=wh21*x1+wh22*x2

h1=sigmoid(v1)
h2=sigmoid(v2)

# printing
print("The activations of hidden neurons are:-")
print("h1: ", h1)
print("h2: ", h2)

print("\n==============\n")

# Output neuron
z1=wo11*h1+wo12*h2
y1=sigmoid(z1)
print("The activations of output neuron is:-")
print("y1: ", y1)

print("\n==============\n")

# Loss Function
L = loss(y1,t1)
print("The Loss is ",L,".")
# Out:
# The activations of hidden neurons are:-
# h1:  0.549833997312478
# h2:  0.574442516811659
#
# ==============
#
# The activations of output neuron is:-
# y1:  0.6375160160941549
#
# ==============
#
# The Loss is  0.003904248244745908 .

# %% [markdown]
# ### Backward Pass

# %%
# Output gradients
grad_wo11 = (y1-t1)*y1*(1-y1)*h1
grad_wo12 = (y1-t1)*y1*(1-y1)*h2
print("Output gradients:-")
print("Gradient of w011: ", grad_wo11)
print("Gradient of w012: ", grad_wo12)

print("\n==============\n")

# Hidden gradients
grad_wh11=(y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)*x1
grad_wh12=(y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)*x2
grad_wh21=(y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)*x1
grad_wh22=(y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)*x2
print("Hidden Gradients:-")
print("Gradient of wh11: ", grad_wh11)
print("Gradient of wh12: ", grad_wh12)
print("Gradient of wh21: ", grad_wh21)
print("Gradient of wh22: ", grad_wh22)

print("\n==============\n")

# updating weights
# hidden neurons
wh11=wh11-alpha*grad_wh11
wh12=wh12-alpha*grad_wh12
wh21=wh21-alpha*grad_wh21
wh22=wh22-alpha*grad_wh22

print("New hidden weights:-")
print("wh11: ", wh11)
print("wh12: ", wh12)
print("wh21: ", wh21)
print("wh22: ", wh22)

print("\n==============\n")

# Output neuron
wo11=wo11-alpha*grad_wo11
wo12=wo12-alpha*grad_wo12

print("New Output Weights:-")
print("w011: ", wo11)
print("w012: ", wo12)
# Out:
# Output gradients:-
# Gradient of w011:  -0.007939263637127044
# Gradient of w012:  -0.008294595473605585
#
# ==============
#
# Hidden Gradients:-
# Gradient of wh11:  -0.00018482410155054986
# Gradient of wh12:  -0.0005544723046516495
# Gradient of wh21:  -0.00036387244992764495
# Gradient of wh22:  -0.0010916173497829346
#
# ==============
#
# New hidden weights:-
# wh11:  0.10036964820310111
# wh12:  0.30110894460930326
# wh21:  0.30072774489985526
# wh22:  0.4021832346995659
#
# ==============
#
# New Output Weights:-
# w011:  0.4158785272742541
# w012:  0.6165891909472111

# %% [markdown]
# ### After one iteration

# %%
# hidden nuerons
v1=wh11*x1+wh12*x2
v2=wh21*x1+wh22*x2

h1=sigmoid(v1)
h2=sigmoid(v2)

# Output neuron
z1=wo11*h1+wo12*h2
y1=sigmoid(z1)

# Loss Function
L = loss(y1,t1)
print("The Loss is ",L,".")
# Out:
# The Loss is  0.0033880583218406156 .

# %% [markdown]
# ## Task 2

# %% [markdown]
# ### Defining initial variables

# %%
# weights
wh11= 0.1
wh12=0.3
wh21=0.3
wh22=0.4
wo11=0.4
wo12=0.6

# input
x1=0.2
x2=0.6

# output
t1=0.7

# learning rate 
alpha=0.1

# loss function
def loss(a,b):
    return (a-b)**2

# activation function
def sigmoid(v):
    return 1/(1+math.exp(-v))

# arrays for plot
mse=[]
itr=[]

# %% [markdown]
# ### Applying loop

# %%
for i in range(1,50):
    itr.append(i)
    # forward pass
    # hidden nuerons
    v1=wh11*x1+wh12*x2
    v2=wh21*x1+wh22*x2

    h1=sigmoid(v1)
    h2=sigmoid(v2)

    # Output neuron
    z1=wo11*h1+wo12*h2
    y1=sigmoid(z1)
    
    # Loss Function
    L = loss(y1,t1)
    mse.append(L)

    # backward propogation
    # Output gradients
    grad_wo11 = (y1-t1)*y1*(1-y1)*h1
    grad_wo12 = (y1-t1)*y1*(1-y1)*h2

    # Hidden gradients
    grad_wh11=(y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)*x1
    grad_wh12=(y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)*x2
    grad_wh21=(y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)*x1
    grad_wh22=(y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)*x2

    # updating weights
    # hidden neurons
    wh11=wh11-alpha*grad_wh11
    wh12=wh12-alpha*grad_wh12
    wh21=wh21-alpha*grad_wh21
    wh22=wh22-alpha*grad_wh22

    # Output neuron
    wo11=wo11-alpha*grad_wo11
    wo12=wo12-alpha*grad_wo12

# %% [markdown]
# ### Plotting the graph

# %%
plt.plot(itr, mse)
plt.xlabel("Iteration")
plt.ylabel("MSE")
plt.show()

# %% [markdown]
# ## Task 3

# %% [markdown]
# ### Defining initial variables

# %%
# weights
wh11=0.1
wh12=0.3
wh21=0.3
wh22=0.4
wo11=0.4
wo12=0.6

# input
x1=0.2
x2=0.6

# output
t1=0.7

# learning rate 
alpha=0.01

# loss function
def loss(a,b):
    return (a-b)**2

# activation function
def sigmoid(v):
    return 1/(1+math.exp(-v))

# arrays for plot
mse1=[]
itr1=[]
rate1=[]

# %% [markdown]
# ### Applying loop

# %%
for i in range(1,50):
    itr1.append(i)
    rate1.append(alpha)
    # forward pass
    # hidden nuerons
    v1=wh11*x1+wh12*x2
    v2=wh21*x1+wh22*x2

    h1=sigmoid(v1)
    h2=sigmoid(v2)

    # Output neuron
    z1=wo11*h1+wo12*h2
    y1=sigmoid(z1)
    
    # Loss Function
    L = loss(y1,t1)
    mse1.append(L)

    # backward propogation
    # Output gradients
    grad_wo11 = (y1-t1)*y1*(1-y1)*h1
    grad_wo12 = (y1-t1)*y1*(1-y1)*h2

    # Hidden gradients
    grad_wh11=(y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)*x1
    grad_wh12=(y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)*x2
    grad_wh21=(y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)*x1
    grad_wh22=(y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)*x2

    # updating weights
    # hidden neurons
    wh11=wh11-alpha*grad_wh11
    wh12=wh12-alpha*grad_wh12
    wh21=wh21-alpha*grad_wh21
    wh22=wh22-alpha*grad_wh22

    # Output neuron
    wo11=wo11-alpha*grad_wo11
    wo12=wo12-alpha*grad_wo12

    alpha=alpha+0.002

# %% [markdown]
# ### Plotting the graph

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot(itr1, rate1, mse1)
plt.xlabel("No of iterations")
plt.ylabel("Learning Rate")
ax.set_zlabel("MSE")

plt.show()

# %% [markdown]
# ## Task 4

# %% [markdown]
# ### Defining initial variables

# %%
# weights
wh11=0.1
wh12=0.3
wh21=0.3
wh22=0.4
wo11=0.4
wo12=0.6

# input
x1=0.2
x2=0.6

# output
t1=0.7

# loss function
def loss(a,b):
    return (a-b)**2

# activation function
def sigmoid(v):
    return 1/(1+math.exp(-v))

# arrays for plot
mse=[]
itr=[]
rate=[]

# %% [markdown]
# ### Applying loop

# %%
for i in range(1,50):
    itr.append(i)
    alpha=0.5*math.exp(-0.05*(i-1))
    rate.append(alpha)
    # forward pass
    # hidden nuerons
    v1=wh11*x1+wh12*x2
    v2=wh21*x1+wh22*x2

    h1=sigmoid(v1)
    h2=sigmoid(v2)

    # Output neuron
    z1=wo11*h1+wo12*h2
    y1=sigmoid(z1)
    
    # Loss Function
    L = loss(y1,t1)
    mse.append(L)

    # backward propogation
    # Output gradients
    grad_wo11 = (y1-t1)*y1*(1-y1)*h1
    grad_wo12 = (y1-t1)*y1*(1-y1)*h2

    # Hidden gradients
    grad_wh11=(y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)*x1
    grad_wh12=(y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)*x2
    grad_wh21=(y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)*x1
    grad_wh22=(y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)*x2

    # updating weights
    # hidden neurons
    wh11=wh11-alpha*grad_wh11
    wh12=wh12-alpha*grad_wh12
    wh21=wh21-alpha*grad_wh21
    wh22=wh22-alpha*grad_wh22

    # Output neuron
    wo11=wo11-alpha*grad_wo11
    wo12=wo12-alpha*grad_wo12

# %% [markdown]
# ### Plotting the graph

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot(itr, rate, mse)
plt.xlabel("No of iterations")
plt.ylabel("Learning Rate")
ax.set_zlabel("MSE")

plt.show()

# %% [markdown]
# ## Task 5

# %% [markdown]
# ### Plotting the graph

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot(itr1, rate1, mse1, label="Task 3")
ax.plot(itr, rate, mse, label="Task 4")
plt.xlabel("No of iterations")
plt.ylabel("Learning Rate")
ax.set_zlabel("MSE")
plt.legend()

plt.show()

# %% [markdown]
# # Q2

# %% [markdown]
# ## Task 1

# %% [markdown]
# ### Defining initial variables

# %%
# weights
wh11=0.5
wh12=-0.3
wh21=0.2
wh22=0.5
wo11=0.1
wo12=0.3

# bias
b1=0.6
b2=-0.4
b3=0.8

# input
x1=1
x2=1

# output
t1=0

# learning rate 
alpha=0.5

# loss function
def loss(a,b):
    return (a-b)**2

# activation function
def sigmoid(v):
    return 1/(1+math.exp(-v))

# %% [markdown]
# ### Forward Pass

# %%
# hidden nuerons
v1=wh11*x1+wh12*x2+b1
v2=wh21*x1+wh22*x2+b2

h1=sigmoid(v1)
h2=sigmoid(v2)

# printing
print("The activations of hidden neurons are:-")
print("h1: ", h1)
print("h2: ", h2)

print("\n==============\n")

# Output neuron
z1=wo11*h1+wo12*h2+b3
y1=sigmoid(z1)
print("The activations of output neuron is:-")
print("y1: ", y1)

print("\n==============\n")

# Loss Function
L = loss(y1,t1)
print("The Loss is ",L,".")
# Out:
# The activations of hidden neurons are:-
# h1:  0.6899744811276125
# h2:  0.574442516811659
#
# ==============
#
# The activations of output neuron is:-
# y1:  0.7391065881217651
#
# ==============
#
# The Loss is  0.5462785486049966 .

# %% [markdown]
# ### Backward Pass

# %%
# Output gradients
grad_wo11 = (y1-t1)*y1*(1-y1)*h1
grad_wo12 = (y1-t1)*y1*(1-y1)*h2
print("Output gradients:-")
print("Gradient of w011: ", grad_wo11)
print("Gradient of w012: ", grad_wo12)

print("\n==============\n")

# Hidden gradients
grad_wh11=(y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)*x1
grad_wh12=(y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)*x2
grad_wh21=(y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)*x1
grad_wh22=(y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)*x2
print("Hidden Gradients:-")
print("Gradient of wh11: ", grad_wh11)
print("Gradient of wh12: ", grad_wh12)
print("Gradient of wh21: ", grad_wh21)
print("Gradient of wh22: ", grad_wh22)

print("\n==============\n")

# bias
grad_b1 = (y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)
grad_b2 = (y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)
grad_b3 = (y1-t1)*y1*(1-y1)
print("Bias Gradients:-")
print("Gradient of b1: ", grad_b1)
print("Gradient of b2: ", grad_b2)
print("Gradient of b3: ", grad_b3)

print("\n==============\n")

# updating
# hidden neurons
wh11=wh11-alpha*grad_wh11
wh12=wh12-alpha*grad_wh12
wh21=wh21-alpha*grad_wh21
wh22=wh22-alpha*grad_wh22

print("New hidden weights:-")
print("wh11: ", wh11)
print("wh12: ", wh12)
print("wh21: ", wh21)
print("wh22: ", wh22)

print("\n==============\n")

# Output neuron
wo11=wo11-alpha*grad_wo11
wo12=wo12-alpha*grad_wo12

print("New Output Weights:-")
print("w011: ", wo11)
print("w012: ", wo12)

# Updating biases
b1 = b1 - alpha * grad_b1
b2 = b2 - alpha * grad_b2
b3 = b3 - alpha * grad_b3

print("Updated Biases:-")
print("b1: ", b1)
print("b2: ", b2)
print("b3: ", b3)
# Out:
# Output gradients:-
# Gradient of w011:  0.0983354903614006
# Gradient of w012:  0.08186982000087041
#
# ==============
#
# Hidden Gradients:-
# Gradient of wh11:  0.0022803275901031633
# Gradient of wh12:  0.0022803275901031633
# Gradient of wh21:  0.008978789886031208
# Gradient of wh22:  0.008978789886031208
#
# ==============
#
# Bias Gradients:-
# Gradient of b1:  0.0022803275901031633
# Gradient of b2:  0.008978789886031208
# Gradient of b3:  0.14252047438144774
#
# ==============
#
# New hidden weights:-
# wh11:  0.4988598362049484
# wh12:  -0.3011401637950516
# wh21:  0.19551060505698442
# wh22:  0.4955106050569844
#
# ==============
#
# New Output Weights:-
# w011:  0.050832254819299705
# w012:  0.2590650899995648
# Updated Biases:-
# b1:  0.5988598362049484
# b2:  -0.4044893949430156
# b3:  0.7287397628092762

# %% [markdown]
# ### After one iteration

# %%
# hidden nuerons
v1=wh11*x1+wh12*x2+b1
v2=wh21*x1+wh22*x2+b2

h1=sigmoid(v1)
h2=sigmoid(v2)

# Output neuron
z1=wo11*h1+wo12*h2+b3
y1=sigmoid(z1)

# Loss Function
L = loss(y1,t1)
print("The Loss is ",L,".")
# Out:
# The Loss is  0.5088768260518785 .

# %% [markdown]
# ## Task 2

# %% [markdown]
# ### Defining initial variables

# %%
# weights
wh11=0.5
wh12=-0.3
wh21=0.2
wh22=0.5
wo11=0.1
wo12=0.3

# bias
b1=0.6
b2=-0.4
b3=0.8

# input
x1=1
x2=1

# output
t1=0

# learning rate 
alpha=0.2

# loss function
def loss(a,b):
    return (a-b)**2

# activation function
def sigmoid(v):
    return 1/(1+math.exp(-v))

# arrays for plot
mse=[]
itr=[]

# %% [markdown]
# ### Applying Loop

# %%
for i in range(1,50):
    itr.append(i)
    # forward pass
    # hidden nuerons
    v1=wh11*x1+wh12*x2+b1
    v2=wh21*x1+wh22*x2+b2

    h1=sigmoid(v1)
    h2=sigmoid(v2)

    # Output neuron
    z1=wo11*h1+wo12*h2+b3
    y1=sigmoid(z1)

    # Loss Function
    L = loss(y1,t1)
    mse.append(L)

    # Output gradients
    grad_wo11 = (y1-t1)*y1*(1-y1)*h1
    grad_wo12 = (y1-t1)*y1*(1-y1)*h2

    # Hidden gradients
    grad_wh11=(y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)*x1
    grad_wh12=(y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)*x2
    grad_wh21=(y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)*x1
    grad_wh22=(y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)*x2

    # bias
    grad_b1 = (y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)
    grad_b2 = (y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)
    grad_b3 = (y1-t1)*y1*(1-y1)

    # updating
    # hidden neurons
    wh11=wh11-alpha*grad_wh11
    wh12=wh12-alpha*grad_wh12
    wh21=wh21-alpha*grad_wh21
    wh22=wh22-alpha*grad_wh22

    # Output neuron
    wo11=wo11-alpha*grad_wo11
    wo12=wo12-alpha*grad_wo12

    # Updating biases
    b1 = b1 - alpha * grad_b1
    b2 = b2 - alpha * grad_b2
    b3 = b3 - alpha * grad_b3

# %% [markdown]
# ### Plotting the graph

# %%
plt.plot(itr, mse)
plt.xlabel("Iteration")
plt.ylabel("MSE")
plt.show()

# %% [markdown]
# ## Task 3

# %% [markdown]
# ### Defining initial variables

# %%
# weights
wh11=0.5
wh12=-0.3
wh21=0.2
wh22=0.5
wo11=0.1
wo12=0.3

# bias
b1=0.6
b2=-0.4
b3=0.8

# input
x1=1
x2=1

# output
t1=0

# learning rate 
alpha=0.02

# loss function
def loss(a,b):
    return (a-b)**2

# activation function
def sigmoid(v):
    return 1/(1+math.exp(-v))

# arrays for plot
mse1=[]
itr1=[]
rate1=[]

# %% [markdown]
# ### Applying Loop

# %%
for i in range(1,50):
    itr1.append(i)
    rate1.append(alpha)
    # forward pass
    # hidden nuerons
    v1=wh11*x1+wh12*x2+b1
    v2=wh21*x1+wh22*x2+b2

    h1=sigmoid(v1)
    h2=sigmoid(v2)

    # Output neuron
    z1=wo11*h1+wo12*h2+b3
    y1=sigmoid(z1)

    # Loss Function
    L = loss(y1,t1)
    mse1.append(L)

    # Output gradients
    grad_wo11 = (y1-t1)*y1*(1-y1)*h1
    grad_wo12 = (y1-t1)*y1*(1-y1)*h2

    # Hidden gradients
    grad_wh11=(y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)*x1
    grad_wh12=(y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)*x2
    grad_wh21=(y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)*x1
    grad_wh22=(y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)*x2

    # bias
    grad_b1 = (y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)
    grad_b2 = (y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)
    grad_b3 = (y1-t1)*y1*(1-y1)

    # updating
    # hidden neurons
    wh11=wh11-alpha*grad_wh11
    wh12=wh12-alpha*grad_wh12
    wh21=wh21-alpha*grad_wh21
    wh22=wh22-alpha*grad_wh22

    # Output neuron
    wo11=wo11-alpha*grad_wo11
    wo12=wo12-alpha*grad_wo12

    # Updating biases
    b1 = b1 - alpha * grad_b1
    b2 = b2 - alpha * grad_b2
    b3 = b3 - alpha * grad_b3

    alpha=alpha + 0.003

# %% [markdown]
# ### Plotting the graph

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot(itr1, rate1, mse1)
plt.xlabel("No of iterations")
plt.ylabel("Learning Rate")
ax.set_zlabel("MSE")

plt.show()

# %% [markdown]
# ## Task 4

# %% [markdown]
# ### Defining initial variables

# %%
# weights
wh11=0.5
wh12=-0.3
wh21=0.2
wh22=0.5
wo11=0.1
wo12=0.3

# bias
b1=0.6
b2=-0.4
b3=0.8

# input
x1=1
x2=1

# output
t1=0

# loss function
def loss(a,b):
    return (a-b)**2

# activation function
def sigmoid(v):
    return 1/(1+math.exp(-v))

# arrays for plot
mse=[]
itr=[]
rate=[]

# %% [markdown]
# ### Applying Loop

# %%
for i in range(1,50):
    alpha=0.4*math.exp(-0.03*i)
    itr.append(i)
    rate.append(alpha)
    # forward pass
    # hidden nuerons
    v1=wh11*x1+wh12*x2+b1
    v2=wh21*x1+wh22*x2+b2

    h1=sigmoid(v1)
    h2=sigmoid(v2)

    # Output neuron
    z1=wo11*h1+wo12*h2+b3
    y1=sigmoid(z1)

    # Loss Function
    L = loss(y1,t1)
    mse.append(L)

    # Output gradients
    grad_wo11 = (y1-t1)*y1*(1-y1)*h1
    grad_wo12 = (y1-t1)*y1*(1-y1)*h2

    # Hidden gradients
    grad_wh11=(y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)*x1
    grad_wh12=(y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)*x2
    grad_wh21=(y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)*x1
    grad_wh22=(y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)*x2

    # bias
    grad_b1 = (y1-t1)*y1*(1-y1)*wo11*v1*(1-v1)
    grad_b2 = (y1-t1)*y1*(1-y1)*wo12*v2*(1-v2)
    grad_b3 = (y1-t1)*y1*(1-y1)

    # updating
    # hidden neurons
    wh11=wh11-alpha*grad_wh11
    wh12=wh12-alpha*grad_wh12
    wh21=wh21-alpha*grad_wh21
    wh22=wh22-alpha*grad_wh22

    # Output neuron
    wo11=wo11-alpha*grad_wo11
    wo12=wo12-alpha*grad_wo12

    # Updating biases
    b1 = b1 - alpha * grad_b1
    b2 = b2 - alpha * grad_b2
    b3 = b3 - alpha * grad_b3

# %% [markdown]
# ### Plotting the graph

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot(itr, rate, mse)
plt.xlabel("No of iterations")
plt.ylabel("Learning Rate")
ax.set_zlabel("MSE")

plt.show()

# %% [markdown]
# ## Task 5

# %% [markdown]
# ### Plotting the graph

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot(itr1, rate1, mse1, label="Task 3")
ax.plot(itr, rate, mse, label="Task 4")
plt.xlabel("No of iterations")
plt.ylabel("Learning Rate")
ax.set_zlabel("MSE")
plt.legend()

plt.show()
